# %% [markdown]
# # Data Cleaning

# %%
# Load the required libraries
import numpy as np
import pandas as pd
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype
import seaborn as sns
import matplotlib.pyplot as plt
import csv
import json
import geojson
import folium
from folium import plugins
from folium.plugins import FastMarkerCluster
from folium.plugins import TimestampedGeoJson
import datetime
import geopandas as gpd
import geoplot
import geoplot.crs as gcrs
import geoplot as gplt
from sklearn.preprocessing import scale
from sklearn import cluster
import statsmodels.api as sm
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing

# %matplotlib inline

# %%
# First, let's read in some airbnb data 

# Import listings data, load as pandas dataframe
listings = pd.read_csv('listings.csv')
# Out:
# C:\Users\vmone\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (61,62,94,95) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Feature Engineering of Distance to CBD 

from geopy.distance import great_circle
def distance_to_mid(lat, lon):
    london_centre = (51.5132, 0.0885) # Using bank station as proxy for CBD 
    accommodation = (lat, lon)
    return great_circle(london_centre, accommodation).km

listings['distance'] = listings.apply(lambda x: distance_to_mid(x.latitude, x.longitude), axis=1)
listings
# Out:
#              id                            listing_url       scrape_id  \
# 0         13913     https://www.airbnb.com/rooms/13913  20200414180850
# 1         15400     https://www.airbnb.com/rooms/15400  20200414180850
# 2         17402     https://www.airbnb.com/rooms/17402  20200414180850
# 3         17506     https://www.airbnb.com/rooms/17506  20200414180850
# 4         25023     https://www.airbnb.com/rooms/25023  20200414180850
# ...         ...                                    ...             ...
# 86353  43184262  https://www.airbnb.com/rooms/43184262  20200414180850
# 86354  43184409  https://www.airbnb.com/rooms/43184409  20200414180850
# 86355  43184488  https://www.airbnb.com/rooms/43184488  20200414180850
# 86356  43185348  https://www.airbnb.com/rooms/43185348  20200414180850
# 86357  43186787  https://www.airbnb.com/rooms/43186787  20200414180850
#
#        last_scraped                                               name  \
# ...

# %%
# Feature selection by visualising variables with many missing values 

percentage_missing_data = listings.isnull().sum() / listings.shape[0]
ax = percentage_missing_data.plot(kind = 'bar', color='#E35A5C', figsize = (16, 5))
ax.set_xlabel('Feature')
ax.set_ylabel('Percent Empty / NaN')
ax.set_title('Feature Emptiness')
plt.show()

# %%
# Select only relevant cols and those without high percentage of missing values 
listings=listings[['id','latitude','longitude','price','review_scores_rating',
                   'neighbourhood_cleansed','distance',
                   'room_type','accommodates','bathrooms','bedrooms','beds',
                   'guests_included','instant_bookable','host_is_superhost','host_response_rate',
                   'number_of_reviews','review_scores_accuracy','review_scores_cleanliness',
                   'review_scores_checkin','review_scores_communication',
                   'review_scores_location','review_scores_value']]

# %%
# counts of listings represented in each neighbourhood
from collections import Counter
nb_counts = Counter(listings.neighbourhood_cleansed)
tdf = pd.DataFrame.from_dict(nb_counts, orient='index').sort_values(by=0)
tdf.plot(kind='bar')

# %%
# remove the $ from the price and convert to float
listings['price'] = listings['price'].replace('[\$,)]','',  \
        regex=True).replace('[(]','-', regex=True).astype(float)
# Out:
# C:\Users\vmone\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# removing empty values or zero values 

listings = listings[listings.bedrooms != 0]
listings = listings[listings.beds != 0]
listings = listings[listings.price != 0]
listings = listings.dropna()
listings
# Out:
#              id  latitude  longitude  price  review_scores_rating  \
# 1         15400  51.48796   -0.16898  100.0                  96.0
# 2         17402  51.52195   -0.14094  300.0                  94.0
# 4         25023  51.44687   -0.21874   65.0                  93.0
# 6         33332  51.46507   -0.32421  100.0                  90.0
# 7         36299  51.47934   -0.28066  195.0                  97.0
# ...         ...       ...        ...    ...                   ...
# 86000  43101031  51.51846   -0.17677  150.0                  80.0
# 86009  43102348  51.48132   -0.42941   60.0                  40.0
# 86079  43114567  51.48015   -0.42897   60.0                 100.0
# 86091  43115959  51.47093    0.04839  128.0                 100.0
# 86106  43119273  51.48290   -0.18296  240.0                 100.0
#
#        neighbourhood_cleansed   distance        room_type  accommodates  \
# 1      Kensington and Chelsea  18.042299  Entire home/apt             2
# ...

# %%
# Dealing with categorical variables using one hot encoding 

listings_numeric = pd.get_dummies(listings)
listings_numeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38351 entries, 1 to 86106
# Data columns (total 60 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   id                                             38351 non-null  int64
#  1   latitude                                       38351 non-null  float64
#  2   longitude                                      38351 non-null  float64
#  3   price                                          38351 non-null  float64
#  4   review_scores_rating                           38351 non-null  float64
#  5   distance                                       38351 non-null  float64
#  6   accommodates                                   38351 non-null  int64
#  7   bathrooms                                      38351 non-null  float64
#  8   bedrooms                                       38351 non-null  float64
# ...

# %%
# manually choose reference level for each categorical variabel and exclude them from the dataframe 
listings_final = listings_numeric.drop(['room_type_Entire home/apt','neighbourhood_cleansed_Westminster','instant_bookable_f','host_is_superhost_f'], axis=1)

#drop latitude and longitude and id for regression 

listings_final = listings_numeric.drop(['latitude','longitude','id'],axis=1)

# double check the result
listings_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38351 entries, 1 to 86106
# Data columns (total 57 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   price                                          38351 non-null  float64
#  1   review_scores_rating                           38351 non-null  float64
#  2   distance                                       38351 non-null  float64
#  3   accommodates                                   38351 non-null  int64
#  4   bathrooms                                      38351 non-null  float64
#  5   bedrooms                                       38351 non-null  float64
#  6   beds                                           38351 non-null  float64
#  7   guests_included                                38351 non-null  int64
#  8   host_response_rate                             38351 non-null  float64
# ...

# %%
# Checking for collinearity between variables 

# Checking for multicollinearity using Pearsons  
df = listings_final
plt.rcParams["axes.grid"] = False
f = plt.figure(figsize=(25, 15))
plt.matshow(df.corr(), fignum=f.number,cmap='BrBG')
plt.xticks(range(df.shape[1]), df.columns, fontsize=14, rotation=90)
plt.yticks(range(df.shape[1]), df.columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix for Model 1A', fontsize=16,y=1.5)
plt.savefig('Corr1A.png',transparent=True)

# %% [markdown]
# # OLS Regression with airbnb rating as dependent variable

# %%
# BASELINE MODEL - OLS Regression with stepwise variable selection and VIF

# %%
# Checking for multicollinearity using VIF
# calculating VIF
# This function is from: https://stackoverflow.com/a/51329496/4667568
from statsmodels.stats.outliers_influence import variance_inflation_factor 
from statsmodels.tools.tools import add_constant

def calculate_vif_(df, thresh=5):
    '''
    Calculates VIF each feature in a pandas dataframe
    A constant must be added to variance_inflation_factor or the results will be incorrect

    :param df: the pandas dataframe containing only the predictor features, not the response variable
    :param thresh: the max VIF value before the feature is removed from the dataframe
    :return: dataframe with features removed
    '''
    const = add_constant(df)
    cols = const.columns
    variables = np.arange(const.shape[1])
    vif_df = pd.Series([variance_inflation_factor(const.values, i) 
               for i in range(const.shape[1])], 
              index=const.columns).to_frame()

    vif_df = vif_df.sort_values(by=0, ascending=False).rename(columns={0: 'VIF'})
    vif_df = vif_df.drop('const')
    vif_df = vif_df[vif_df['VIF'] > thresh]

    print('Features above VIF threshold:\n')
    print(vif_df[vif_df['VIF'] > thresh])

    col_to_drop = list(vif_df.index)

    for i in col_to_drop:
        print('Dropping: {}'.format(i))
        df = df.drop(columns=i)

    return df

# %%
# split the DataFrame into predictors and response
predictors_listings = listings_final.drop(columns=['review_scores_rating'], axis=1)
response_listings = listings_final[['review_scores_rating']]

# %%
# using VIF on the airbnb dataset
df_predictors_select_VIF = calculate_vif_(predictors_listings)
print("The columns remaining after VIF selection are:")
print(df_predictors_select_VIF.columns)

# accomodates and distance variable is above threshold
# Out:
# C:\Users\vmone\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1685: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# C:\Users\vmone\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# Features above VIF threshold:
#
#                                                      VIF
# neighbourhood_cleansed_Hammersmith and Fulham        inf
# neighbourhood_cleansed_Haringey                      inf
# neighbourhood_cleansed_Havering                      inf
# neighbourhood_cleansed_Hillingdon                    inf
# neighbourhood_cleansed_Hounslow                      inf
# neighbourhood_cleansed_Islington                     inf
# neighbourhood_cleansed_Kensington and Chelsea        inf
# neighbourhood_cleansed_Kingston upon Thames          inf
# ...

# %%
# # fit a linear regression model using statsmodel
regressor_OLS = sm.OLS(endog=response_listings, exog=sm.add_constant(df_predictors_select_VIF)).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     review_scores_rating   R-squared:                       0.792
# Model:                              OLS   Adj. R-squared:                  0.792
# Method:                   Least Squares   F-statistic:                 1.124e+04
# Date:                  Tue, 26 May 2020   Prob (F-statistic):               0.00
# Time:                          09:48:25   Log-Likelihood:            -1.1198e+05
# No. Observations:                 38351   AIC:                         2.240e+05
# Df Residuals:                     38337   BIC:                         2.241e+05
# Df Model:                            13
# Covariance Type:              nonrobust
# ...
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# ...

# %%
# Stepwise selection 
# This code comes from the module of Quantitative Methods (CASA0007), and is prepared by Dr Thomas Evans

def stepwise_selection(X, y, 
                       initial_list=[], 
                       threshold_in=0.01, 
                       threshold_out = 0.05, 
                       verbose=True):
    """ Perform a forward-backward feature selection 
    based on p-value from statsmodels.api.OLS
    Arguments:
        X - pandas.DataFrame with candidate features
        y - list-like with the target
        initial_list - list of features to start with (column names of X)
        threshold_in - include a feature if its p-value < threshold_in
        threshold_out - exclude a feature if its p-value > threshold_out
        verbose - whether to print the sequence of inclusions and exclusions
    Returns: list of selected features 
    Always set threshold_in < threshold_out to avoid infinite looping.
    See https://en.wikipedia.org/wiki/Stepwise_regression for the details
    """
    included = list(initial_list)
    while True:
        changed=False
        # forward step
        excluded = list(set(X.columns)-set(included))
        new_pval = pd.Series(index=excluded)
        for new_column in excluded:
            model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[included+[new_column]]))).fit()
            new_pval[new_column] = model.pvalues[new_column]
        best_pval = new_pval.min()
        if best_pval < threshold_in:
            best_feature = new_pval.idxmin()
            included.append(best_feature)
            changed=True
            if verbose:
                print('Add  {:30} with p-value {:.6}'.format(best_feature, best_pval))

        # backward step
        model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[included]))).fit()
        # use all coefs except intercept
        pvalues = model.pvalues.iloc[1:]
        worst_pval = pvalues.max() # null if pvalues is empty
        if worst_pval > threshold_out:
            changed=True
            worst_feature = pvalues.argmax()
            included.remove(worst_feature)
            if verbose:
                print('Drop {:30} with p-value {:.6}'.format(worst_feature, worst_pval))
        if not changed:
            break
    return included

# %%
# use stepwise regression on dataset
list_predictor_select_stepwise = stepwise_selection(X=predictors_listings, y=response_listings)
print("The predictors that are selected by stepwise regression are:")
print(list_predictor_select_stepwise)
# Out:
# C:\Users\vmone\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# Add  review_scores_communication    with p-value 0.0
# Add  review_scores_location         with p-value 0.0
# Add  review_scores_cleanliness      with p-value 0.0
# Add  review_scores_value            with p-value 0.0
# Add  review_scores_accuracy         with p-value 0.0
# Add  instant_bookable_t             with p-value 2.97794e-44
# Add  bedrooms                       with p-value 9.36651e-35
# Add  host_is_superhost_t            with p-value 4.23782e-39
# Add  host_is_superhost_f            with p-value 3.86392e-54
# Add  number_of_reviews              with p-value 2.33867e-36
# Add  review_scores_checkin          with p-value 1.34248e-29
# Add  instant_bookable_f             with p-value 1.20849e-26
# ...

# %%
# fit linear regression model using predictors from stepwise regression
# array for exog 
test=listings_final[list_predictor_select_stepwise]
regressor_OLS = sm.OLS(endog=response_listings, exog=sm.add_constant(test)).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     review_scores_rating   R-squared:                       0.795
# Model:                              OLS   Adj. R-squared:                  0.795
# Method:                   Least Squares   F-statistic:                     6750.
# Date:                  Mon, 25 May 2020   Prob (F-statistic):               0.00
# Time:                          18:20:27   Log-Likelihood:            -1.1173e+05
# No. Observations:                 38351   AIC:                         2.235e+05
# Df Residuals:                     38328   BIC:                         2.237e+05
# Df Model:                            22
# Covariance Type:              nonrobust
# ...
#                                                     coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
# encoding of categorical variables for random forest regression 

# Function to label encode categorical variables.
# Input: array (array of values)
# Output: array (array of encoded values)
def encode_categorical(array):
    if not array.dtype == np.dtype('float64'):
        return preprocessing.LabelEncoder().fit_transform(array) 
    else:
        return array
    
# Temporary dataframe
temp_data = listings.copy()

# Encode categorical data
temp_data = temp_data.apply(encode_categorical)
temp_data
# Out:
#           id  latitude  longitude  price  review_scores_rating  \
# 1          0  51.48796   -0.16898  100.0                  96.0
# 2          1  51.52195   -0.14094  300.0                  94.0
# 4          2  51.44687   -0.21874   65.0                  93.0
# 6          3  51.46507   -0.32421  100.0                  90.0
# 7          4  51.47934   -0.28066  195.0                  97.0
# ...      ...       ...        ...    ...                   ...
# 86000  38346  51.51846   -0.17677  150.0                  80.0
# 86009  38347  51.48132   -0.42941   60.0                  40.0
# 86079  38348  51.48015   -0.42897   60.0                 100.0
# 86091  38349  51.47093    0.04839  128.0                 100.0
# 86106  38350  51.48290   -0.18296  240.0                 100.0
#
#        neighbourhood_cleansed   distance  room_type  accommodates  bathrooms  \
# 1                          19  18.042299          0             1        1.0
# ...

# %%
# Data splitting into training and test set 

# Shuffle the data to ensure a good distribution for the training and testing sets
from sklearn.utils import shuffle
listings = shuffle(listings)

# Extract features and labels
y = temp_data['review_scores_rating']
X = temp_data.drop('review_scores_rating', axis = 1)

# Training and Testing Sets
from sklearn.model_selection import train_test_split
train_X, test_X, train_y, test_y = train_test_split(X, y, random_state = 0)

train_X = np.array(train_X)
test_X = np.array(test_X)
train_y = np.array(train_y)
test_y = np.array(test_y)

train_X.shape, test_X.shape
# Out:
# ((28763, 22), (9588, 22))

# %% [markdown]
# # Random Forest Regression

# %%
# Random Forest 

# Create the pipeline (scaler + regressor)
pipeline_RF = make_pipeline(StandardScaler(), RandomForestRegressor(random_state=0))

# Fit the model
pipeline_RF.fit(train_X, train_y)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestregressor',
#                  RandomForestRegressor(random_state=0))])

# %%
# RF model evaluation 
from sklearn.metrics import median_absolute_error
from sklearn.metrics import mean_squared_error
from math import sqrt

def evaluate_model(model, predict_set, evaluate_set):
    predictions = model.predict(predict_set)
    print("Median Absolute Error: " + str(round(median_absolute_error(predictions, evaluate_set), 2))) 
    RMSE = round(sqrt(mean_squared_error(predictions, evaluate_set)), 2)
    print("RMSE: " + str(RMSE))

# %%
evaluate_model(pipeline_RF, test_X, test_y)
# Out:
# Median Absolute Error: 1.65
# RMSE: 4.47

# %%
# Feature Importance 

importances = pipeline_RF.steps[1][1].feature_importances_
feature_importances = pd.DataFrame({"feature":X.columns.values, "importance":importances})
feature_importances.sort_values("importance", ascending=False)
# Out:
#                         feature  importance
# 16       review_scores_accuracy    0.427518
# 21          review_scores_value    0.286980
# 17    review_scores_cleanliness    0.058542
# 19  review_scores_communication    0.029755
# 0                            id    0.027736
# 3                         price    0.021760
# 1                      latitude    0.021587
# 15            number_of_reviews    0.021038
# 5                      distance    0.015733
# 2                     longitude    0.015403
# 4        neighbourhood_cleansed    0.010885
# 18        review_scores_checkin    0.010247
# 14           host_response_rate    0.008869
# 7                  accommodates    0.007290
# 20       review_scores_location    0.007286
# 8                     bathrooms    0.005798
# 11              guests_included    0.005575
# 10                         beds    0.004952
# 13            host_is_superhost    0.004658
# 12             instant_bookable    0.003533
# ...

# %%
# Visualistion of the most important features 
feature_importances = pd.Series(pipeline_RF.steps[1][1].feature_importances_, index=X.columns)
feature_importances.sort_values(ascending=True).plot(kind='barh', color='darkgrey', figsize=(10,5))
plt.xlabel('Relative Feature Importance with Random Forest')
# Out:
# Text(0.5, 0, 'Relative Feature Importance with Random Forest')

# %% [markdown]
# # Extracting Total Count, Average Price, Rating and Other Parameters of Airbnbs within Neighbourhood

# %%
# Load the geojson file required for creating geodataframe
london_geo = gpd.GeoDataFrame.from_file('neighbourhoods.geojson')
# Drop the column neighbourhood_group, no useful data
london_geo.drop(columns=['neighbourhood_group'],inplace=True)
london_geo
# Out:
#              neighbourhood                                           geometry
# 0     Kingston upon Thames  MULTIPOLYGON (((-0.33068 51.32901, -0.33059 51...
# 1                  Croydon  MULTIPOLYGON (((-0.06402 51.31864, -0.06407 51...
# 2                  Bromley  MULTIPOLYGON (((0.01213 51.29960, 0.01196 51.2...
# 3                 Hounslow  MULTIPOLYGON (((-0.24456 51.48870, -0.24468 51...
# 4                   Ealing  MULTIPOLYGON (((-0.41183 51.53408, -0.41188 51...
# 5                 Havering  MULTIPOLYGON (((0.15869 51.51219, 0.15871 51.5...
# 6               Hillingdon  MULTIPOLYGON (((-0.40407 51.61318, -0.40388 51...
# 7                   Harrow  MULTIPOLYGON (((-0.40407 51.61318, -0.40320 51...
# 8                    Brent  MULTIPOLYGON (((-0.19657 51.52765, -0.19685 51...
# 9                   Barnet  MULTIPOLYGON (((-0.19990 51.67017, -0.19970 51...
# 10                 Enfield  MULTIPOLYGON (((-0.10580 51.69187, -0.10557 51...
# ...

# %%
# Create new dataframe for total listings grouped by neighbourhood
listings_geo = pd.DataFrame(listings.groupby(['neighbourhood_cleansed']).id.count()).reset_index()

# Rename column in neighbourhood_cleansed dataframe
listings_geo.rename(columns={'neighbourhood_cleansed':'neighbourhood','id':'listings'}, 
                 inplace=True)

# %%
# Merge total listings dataframe with london_geo 
london_geo = london_geo.merge(listings_geo, on='neighbourhood')
london_geo
# Out:
#              neighbourhood                                           geometry  \
# 0     Kingston upon Thames  MULTIPOLYGON (((-0.33068 51.32901, -0.33059 51...
# 1                  Croydon  MULTIPOLYGON (((-0.06402 51.31864, -0.06407 51...
# 2                  Bromley  MULTIPOLYGON (((0.01213 51.29960, 0.01196 51.2...
# 3                 Hounslow  MULTIPOLYGON (((-0.24456 51.48870, -0.24468 51...
# 4                   Ealing  MULTIPOLYGON (((-0.41183 51.53408, -0.41188 51...
# 5                 Havering  MULTIPOLYGON (((0.15869 51.51219, 0.15871 51.5...
# 6               Hillingdon  MULTIPOLYGON (((-0.40407 51.61318, -0.40388 51...
# 7                   Harrow  MULTIPOLYGON (((-0.40407 51.61318, -0.40320 51...
# 8                    Brent  MULTIPOLYGON (((-0.19657 51.52765, -0.19685 51...
# 9                   Barnet  MULTIPOLYGON (((-0.19990 51.67017, -0.19970 51...
# 10                 Enfield  MULTIPOLYGON (((-0.10580 51.69187, -0.10557 51...
# ...

# %%
# Create new dataframe for listings grouped by neighbourhood
average_geo = pd.DataFrame(listings.groupby(['neighbourhood_cleansed']).mean()).reset_index()
average_geo = average_geo.drop(['id','latitude','longitude'],axis=1)

# %%
# Rename column in neighbourhood_cleansed dataframe
average_geo.rename(columns={'neighbourhood_cleansed':'neighbourhood','id':'listings'}, 
                 inplace=True)
average_geo
# Out:
#              neighbourhood       price  review_scores_rating   distance  \
# 0     Barking and Dagenham   61.343750             92.850000   4.270214
# 1                   Barnet   84.575194             93.516279  22.470135
# 2                   Bexley   60.855769             95.000000   6.981420
# 3                    Brent   92.529676             92.372302  22.869732
# 4                  Bromley   64.628676             94.889706  14.398077
# 5                   Camden  150.903286             91.169327  16.320453
# 6           City of London  188.378277             89.726592  12.586220
# 7                  Croydon   62.074419             93.709302  19.421320
# 8                   Ealing   86.076923             93.590186  26.743850
# 9                  Enfield   67.638436             92.863192  18.308606
# 10               Greenwich   97.003827             93.808673   5.274885
# 11                 Hackney  102.940167             94.436920  11.575883
# ...

# %%
# Merge average values dataframe with geojson file 
london_geo = london_geo.merge(average_geo, on='neighbourhood')

# %%
centroids = pd.read_csv('centroids.csv')
centroids = centroids[['name','centroid_x','centroid_y']]
centroids
# Out:
#                       name  centroid_x  centroid_y
# 0     Barking and Dagenham    0.134829   51.543400
# 1                   Barnet   -0.208418   51.615501
# 2                   Bexley    0.144004   51.460400
# 3                    Brent   -0.266242   51.558102
# 4                  Bromley    0.053151   51.371498
# 5                   Camden   -0.155813   51.545898
# 6           City of London   -0.090804   51.513901
# 7                  Croydon   -0.085559   51.354801
# 8                   Ealing   -0.329450   51.521999
# 9                  Enfield   -0.085666   51.650501
# 10               Greenwich    0.057194   51.473900
# 11                 Hackney   -0.061718   51.551800
# 12  Hammersmith and Fulham   -0.219204   51.494499
# 13                Haringey   -0.105878   51.589901
# 14                  Harrow   -0.339683   51.597198
# 15                Havering    0.222064   51.562599
# 16              Hillingdon   -0.444089   51.541000
# ...

# %%
# Rename column in neighbourhood_cleansed dataframe
centroids.rename(columns={'name':'neighbourhood','id':'listings'}, 
                 inplace=True)
centroids
# Out:
#              neighbourhood  centroid_x  centroid_y
# 0     Barking and Dagenham    0.134829   51.543400
# 1                   Barnet   -0.208418   51.615501
# 2                   Bexley    0.144004   51.460400
# 3                    Brent   -0.266242   51.558102
# 4                  Bromley    0.053151   51.371498
# 5                   Camden   -0.155813   51.545898
# 6           City of London   -0.090804   51.513901
# 7                  Croydon   -0.085559   51.354801
# 8                   Ealing   -0.329450   51.521999
# 9                  Enfield   -0.085666   51.650501
# 10               Greenwich    0.057194   51.473900
# 11                 Hackney   -0.061718   51.551800
# 12  Hammersmith and Fulham   -0.219204   51.494499
# 13                Haringey   -0.105878   51.589901
# 14                  Harrow   -0.339683   51.597198
# 15                Havering    0.222064   51.562599
# 16              Hillingdon   -0.444089   51.541000
# ...

# %%
# merge centroids data with dataframe
london_geo = london_geo.merge(centroids, on='neighbourhood')

# %%
# Open geodataframe to be imported to MySQL database 
london_geo
# Out:
#              neighbourhood                                           geometry  \
# 0     Kingston upon Thames  MULTIPOLYGON (((-0.33068 51.32901, -0.33059 51...
# 1                  Croydon  MULTIPOLYGON (((-0.06402 51.31864, -0.06407 51...
# 2                  Bromley  MULTIPOLYGON (((0.01213 51.29960, 0.01196 51.2...
# 3                 Hounslow  MULTIPOLYGON (((-0.24456 51.48870, -0.24468 51...
# 4                   Ealing  MULTIPOLYGON (((-0.41183 51.53408, -0.41188 51...
# 5                 Havering  MULTIPOLYGON (((0.15869 51.51219, 0.15871 51.5...
# 6               Hillingdon  MULTIPOLYGON (((-0.40407 51.61318, -0.40388 51...
# 7                   Harrow  MULTIPOLYGON (((-0.40407 51.61318, -0.40320 51...
# 8                    Brent  MULTIPOLYGON (((-0.19657 51.52765, -0.19685 51...
# 9                   Barnet  MULTIPOLYGON (((-0.19990 51.67017, -0.19970 51...
# 10                 Enfield  MULTIPOLYGON (((-0.10580 51.69187, -0.10557 51...
# ...

# %%
## Insert the london_geo dataframe with airbnb description data to MySQL

import shapely
from shapely.geometry import LineString, shape, MultiPolygon, Point
from shapely.wkt import dumps

#Reduce the precision of coordinate of polygon to avoid the error 1406 when upload to mySQL
london_geo['geometry'] = london_geo['geometry'].apply(lambda x: shapely.wkt.loads(shapely.wkt.dumps(x, rounding_precision=4)))

#Convert the coordinates of polygon as WKT string for uploading to mysql
london_geo['geometry'] = london_geo['geometry'].apply(lambda x: x.wkt)

# %%
# import the SQLAlchemy libraries
from sqlalchemy import create_engine

#Connect to SQL with Character Set utf8mb4
engine = create_engine('mysql+pymysql://ucfnyle:wehomihiga@dev.spatialdatacapture.org:3306/ucfnyle?charset=utf8mb4')

# make the connection to the database
conn = engine.raw_connection()

#Upload the finalized geodataframe to mysql
london_geo.to_sql('airbnb_data', engine, if_exists='replace')

# %% [markdown]
# # Data Prep for Borough-Level Regression

# %%
# Read in combined csv file that includes these average price and rating of airbnbs and joined to london borough census data

london_data = pd.read_csv('london_boroughs.csv')
london_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   New code                           33 non-null     object
#  1   Area name                          33 non-null     object
#  2   Total_airbnbs                      33 non-null     int64
#  3   Avg_rating                         33 non-null     float64
#  4   Avg_price                          33 non-null     float64
#  5   Two-year business survival rates   33 non-null     float64
#  6   Unemployment_Rate                  33 non-null     float64
#  7   Ethnic_diversity_index             33 non-null     float64
#  8   Median Household Income 2015       33 non-null     int64
#  9   Median House Price                 33 non-null     int64
#  10  %_level4_qualification             33 non-null     float64
# ...

# %% [markdown]
# # Regression with average price of airbnb within borough as dependent variable

# %%
# Check for multicollinearity 

df = london_data.drop(['New code','Area name'],axis=1)
plt.rcParams["axes.grid"] = False
f = plt.figure(figsize=(19, 15))
plt.matshow(df.corr(), fignum=f.number,cmap="BrBG")
plt.xticks(range(df.shape[1]), df.columns, fontsize=14, rotation=45)
plt.yticks(range(df.shape[1]), df.columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix for Model 2A', fontsize=16, y=1)
plt.savefig('Corr2A.png',transparent=True)

# We observe some correlation between independent variables, therefore use VIF as a guide to which variables should be dropped

# %%
# split the DataFrame into predictors and response
predictors_listings = df.drop(columns=['Avg_price'], axis=1)
response_listings = df[['Avg_price']]

# %%
# VIF

# using VIF on the london borough dataset
df_predictors_select_VIF = calculate_vif_(predictors_listings)
print("The columns remaining after VIF selection are:")
print(df_predictors_select_VIF.columns)

# none of the features are above VIF threshold, which is good
# Out:
# Features above VIF threshold:
#
#                                     VIF
# Median Household Income 2015  27.456806
# Median House Price            22.094939
# Public_transport_access       16.213167
# Crime_Rate_Per_1000           11.365765
# %_level4_qualification         6.654356
# Dropping: Median Household Income 2015
# Dropping: Median House Price
# Dropping: Public_transport_access
# Dropping: Crime_Rate_Per_1000
# Dropping: %_level4_qualification
# The columns remaining after VIF selection are:
# Index(['Total_airbnbs', 'Avg_rating', 'Two-year business survival rates ',
#        'Unemployment_Rate', 'Ethnic_diversity_index', 'Median_Age'],
#       dtype='object')

# %%
# fit a linear regression model using statsmodel
regressor_OLS = sm.OLS(endog=response_listings, exog=sm.add_constant(df_predictors_select_VIF)).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              Avg_price   R-squared:                       0.623
# Model:                            OLS   Adj. R-squared:                  0.536
# Method:                 Least Squares   F-statistic:                     7.155
# Date:                Mon, 25 May 2020   Prob (F-statistic):           0.000139
# Time:                        18:22:41   Log-Likelihood:                -153.65
# No. Observations:                  33   AIC:                             321.3
# Df Residuals:                      26   BIC:                             331.8
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# ...

# %%
# Stepwise variable selection 

# use stepwise regression on dataset
import statsmodels.api as sm
list_predictor_select_stepwise = stepwise_selection(X=predictors_listings, y=response_listings)
print("The predictors that are selected by stepwise regression are:")
print(list_predictor_select_stepwise)
# Out:
# Add  Median House Price             with p-value 3.33715e-17
# Add  Crime_Rate_Per_1000            with p-value 1.54428e-05
# The predictors that are selected by stepwise regression are:
# ['Median House Price', 'Crime_Rate_Per_1000']
# C:\Users\vmone\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.

# %%
# fit linear regression model using predictors from stepwise regression
# array for exog 
test=df[list_predictor_select_stepwise]
regressor_OLS = sm.OLS(endog=response_listings, exog=sm.add_constant(test)).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              Avg_price   R-squared:                       0.948
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     273.8
# Date:                Mon, 25 May 2020   Prob (F-statistic):           5.41e-20
# Time:                        18:22:44   Log-Likelihood:                -120.94
# No. Observations:                  33   AIC:                             247.9
# Df Residuals:                      30   BIC:                             252.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
import statsmodels.formula.api as smf
df=pd.read_csv('london_boroughs copy.csv')
df
# Out:
#      Avg_price  Avg_rating  Total_airbnbs  Two_year_business_survival_rates  \
# 0   188.378277   89.726592            160                              64.3
# 1    61.343750   92.850000            645                              73.0
# 2    84.575194   93.516279            104                              73.8
# 3    60.855769   95.000000           1112                              73.5
# 4    92.529676   92.372302            272                              74.4
# 5    64.628676   94.889706           3195                              78.6
# 6   150.903286   91.169327            267                              73.6
# 7    62.074419   93.709302            430                              75.3
# 8    86.076923   93.590186            754                              75.8
# 9    67.638436   92.863192            307                              74.2
# 10   97.003827   93.808673            784                              72.7
# ...

# %%
model = smf.ols(formula='Avg_price ~ Median_Household_Income + Median_Age', data=df).fit()


# And this gives a big summary of the results:
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              Avg_price   R-squared:                       0.848
# Model:                            OLS   Adj. R-squared:                  0.838
# Method:                 Least Squares   F-statistic:                     83.97
# Date:                Mon, 25 May 2020   Prob (F-statistic):           5.11e-13
# Time:                        18:22:48   Log-Likelihood:                -138.61
# No. Observations:                  33   AIC:                             283.2
# Df Residuals:                      30   BIC:                             287.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                 177.2559     37.782      4.692      0.000     100.095     254.416
# ...

# %%
# Data splitting into training and test set 

# Shuffle the data to ensure a good distribution for the training and testing sets
from sklearn.utils import shuffle
listings = shuffle(listings)

# Extract features and labels
y = df['Avg_price']
X = df.drop('Avg_price', axis = 1)

# Training and Testing Sets
from sklearn.model_selection import train_test_split
train_X, test_X, train_y, test_y = train_test_split(X, y, random_state = 0)

train_X = np.array(train_X)
test_X = np.array(test_X)
train_y = np.array(train_y)
test_y = np.array(test_y)

train_X.shape, test_X.shape
# Out:
# ((24, 11), (9, 11))

# %%
# Random Forest Regression

# Create the pipeline (scaler + regressor)
pipeline_RF_lb = make_pipeline(StandardScaler(), RandomForestRegressor(random_state=0))

# Fit the model
pipeline_RF_lb.fit(train_X, train_y)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestregressor',
#                  RandomForestRegressor(random_state=0))])

# %%
# model evaluation 
evaluate_model(pipeline_RF_lb, test_X, test_y)
# Out:
# Median Absolute Error: 7.7
# RMSE: 14.98

# %%
importances = pipeline_RF_lb.steps[1][1].feature_importances_
feature_importances = pd.DataFrame({"feature":X.columns.values, "importance":importances})
feature_importances.sort_values("importance", ascending=False)
# Out:
#                              feature  importance
# 6                 Median_House_Price    0.533452
# 5            Median_Household_Income    0.121782
# 7           pct_level4_qualification    0.091435
# 10               Crime_Rate_Per_1000    0.070239
# 8            Public_transport_access    0.062614
# 0                         Avg_rating    0.053445
# 9                         Median_Age    0.021689
# 1                      Total_airbnbs    0.019863
# 2   Two_year_business_survival_rates    0.014755
# 4             Ethnic_diversity_index    0.005831
# 3                  Unemployment_Rate    0.004895

# %%
# Visualistion of most important features 
feature_importances = pd.Series(pipeline_RF_lb.steps[1][1].feature_importances_, index=X.columns)
feature_importances.sort_values(ascending=True).plot(kind='barh', color='darkgrey', figsize=(10,5))
plt.xlabel('Relative Feature Importance with Random Forest')
# Out:
# Text(0.5, 0, 'Relative Feature Importance with Random Forest')

# %% [markdown]
# # Regression with average rating of airbnb within borough as dependent variable

# %%
# split the DataFrame into predictors and response
predictors_listings = df.drop(columns=['Avg_rating'], axis=1)
response_listings = df[['Avg_rating']]

# %%
# VIF

# using VIF on the london borough dataset
df_predictors_select_VIF = calculate_vif_(predictors_listings)
print("The columns remaining after VIF selection are:")
print(df_predictors_select_VIF.columns)

# none of the features are above VIF threshold, which is good
# Out:
# Features above VIF threshold:
#
#                                 VIF
# Median_House_Price        29.516041
# Median_Household_Income   26.891567
# Avg_price                 26.633744
# Public_transport_access   17.351128
# Crime_Rate_Per_1000       15.413439
# pct_level4_qualification   7.046595
# Dropping: Median_House_Price
# Dropping: Median_Household_Income
# Dropping: Avg_price
# Dropping: Public_transport_access
# Dropping: Crime_Rate_Per_1000
# Dropping: pct_level4_qualification
# The columns remaining after VIF selection are:
# Index(['Total_airbnbs', 'Two_year_business_survival_rates',
#        'Unemployment_Rate', 'Ethnic_diversity_index', 'Median_Age'],
#       dtype='object')

# %%
# fit a linear regression model using statsmodel
regressor_OLS = sm.OLS(endog=response_listings, exog=sm.add_constant(df_predictors_select_VIF)).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             Avg_rating   R-squared:                       0.374
# Model:                            OLS   Adj. R-squared:                  0.258
# Method:                 Least Squares   F-statistic:                     3.223
# Date:                Mon, 25 May 2020   Prob (F-statistic):             0.0208
# Time:                        18:23:01   Log-Likelihood:                -49.353
# No. Observations:                  33   AIC:                             110.7
# Df Residuals:                      27   BIC:                             119.7
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...

# %%
# Stepwise variable selection 

# use stepwise regression on dataset
import statsmodels.api as sm
list_predictor_select_stepwise = stepwise_selection(X=predictors_listings, y=response_listings)
print("The predictors that are selected by stepwise regression are:")
print(list_predictor_select_stepwise)
# Out:
# Add  Crime_Rate_Per_1000            with p-value 8.30693e-06
# The predictors that are selected by stepwise regression are:
# ['Crime_Rate_Per_1000']
# C:\Users\vmone\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.

# %%
# fit linear regression model using predictors from stepwise regression
# array for exog 
test=df[list_predictor_select_stepwise]
regressor_OLS = sm.OLS(endog=response_listings, exog=sm.add_constant(test)).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             Avg_rating   R-squared:                       0.478
# Model:                            OLS   Adj. R-squared:                  0.461
# Method:                 Least Squares   F-statistic:                     28.42
# Date:                Mon, 25 May 2020   Prob (F-statistic):           8.31e-06
# Time:                        18:23:04   Log-Likelihood:                -46.338
# No. Observations:                  33   AIC:                             96.68
# Df Residuals:                      31   BIC:                             99.67
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
# Data splitting into training and test set 

# Shuffle the data to ensure a good distribution for the training and testing sets
from sklearn.utils import shuffle
listings = shuffle(listings)

# Extract features and labels
y = df['Avg_rating']
X = df.drop('Avg_rating', axis = 1)

# Training and Testing Sets
from sklearn.model_selection import train_test_split
train_X, test_X, train_y, test_y = train_test_split(X, y, random_state = 0)

train_X = np.array(train_X)
test_X = np.array(test_X)
train_y = np.array(train_y)
test_y = np.array(test_y)

train_X.shape, test_X.shape
# Out:
# ((24, 11), (9, 11))

# %%
# Random Forest Regression

# Create the pipeline (scaler + regressor)
pipeline_RF_lb = make_pipeline(StandardScaler(), RandomForestRegressor(random_state=0))

# Fit the model
pipeline_RF_lb.fit(train_X, train_y)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestregressor',
#                  RandomForestRegressor(random_state=0))])

# %%
# model evaluation 
evaluate_model(pipeline_RF_lb, test_X, test_y)
# Out:
# Median Absolute Error: 1.02
# RMSE: 1.19

# %%
# Feature Importance 

importances = pipeline_RF_lb.steps[1][1].feature_importances_
feature_importances = pd.DataFrame({"feature":X.columns.values, "importance":importances})
feature_importances.sort_values("importance", ascending=False)

# Visualistion of most important features 
feature_importances = pd.Series(pipeline_RF_lb.steps[1][1].feature_importances_, index=X.columns)
feature_importances.sort_values(ascending=True).plot(kind='barh', color='darkgrey', figsize=(10,5))
plt.xlabel('Relative Feature Importance with Random Forest')
# Out:
# Text(0.5, 0, 'Relative Feature Importance with Random Forest')

# %% [markdown]
# # K-Means Clustering/ Geodemographic Classification of Neighbourhoods
# #### We are interested in clustering the london boroughs based on the similarity between the observed airbnbs within these neighbourhoods

# %%
# Load the geojson file required for mapping as a geodataframe
lb = gpd.GeoDataFrame.from_file('neighbourhoods.geojson')
lb
# Out:
#              neighbourhood neighbourhood_group  \
# 0     Kingston upon Thames                None
# 1                  Croydon                None
# 2                  Bromley                None
# 3                 Hounslow                None
# 4                   Ealing                None
# 5                 Havering                None
# 6               Hillingdon                None
# 7                   Harrow                None
# 8                    Brent                None
# 9                   Barnet                None
# 10                 Enfield                None
# 11          Waltham Forest                None
# 12               Redbridge                None
# 13                  Sutton                None
# 14                 Lambeth                None
# 15               Southwark                None
# 16                Lewisham                None
# 17               Greenwich                None
# 18                  Bexley                None
# ...

# %%
# create subset of variables to perform clustering on 
sub_list = ['price','review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness',
     'review_scores_checkin', 'review_scores_communication', 'review_scores_location',
     'review_scores_value']

# %%
# Find average of all values by neighbourhood 
db = listings.groupby('neighbourhood_cleansed')[sub_list].mean()
# check dataframe
db.info()
# open dataframe
db
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, Barking and Dagenham to Westminster
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   price                        33 non-null     float64
#  1   review_scores_rating         33 non-null     float64
#  2   review_scores_accuracy       33 non-null     float64
#  3   review_scores_cleanliness    33 non-null     float64
#  4   review_scores_checkin        33 non-null     float64
#  5   review_scores_communication  33 non-null     float64
#  6   review_scores_location       33 non-null     float64
#  7   review_scores_value          33 non-null     float64
# dtypes: float64(8)
# memory usage: 2.3+ KB
#                              price  review_scores_rating  \
# neighbourhood_cleansed
# Barking and Dagenham     61.343750             92.850000
# Barnet                   84.575194             93.516279
# ...

# %%
# join dataset to neighbourhoods file 

zdb = lb[['geometry','neighbourhood']].join(db, on='neighbourhood')\
                                         .dropna()
zdb
# Out:
#                                              geometry           neighbourhood  \
# 0   MULTIPOLYGON (((-0.33068 51.32901, -0.33059 51...    Kingston upon Thames
# 1   MULTIPOLYGON (((-0.06402 51.31864, -0.06407 51...                 Croydon
# 2   MULTIPOLYGON (((0.01213 51.29960, 0.01196 51.2...                 Bromley
# 3   MULTIPOLYGON (((-0.24456 51.48870, -0.24468 51...                Hounslow
# 4   MULTIPOLYGON (((-0.41183 51.53408, -0.41188 51...                  Ealing
# 5   MULTIPOLYGON (((0.15869 51.51219, 0.15871 51.5...                Havering
# 6   MULTIPOLYGON (((-0.40407 51.61318, -0.40388 51...              Hillingdon
# 7   MULTIPOLYGON (((-0.40407 51.61318, -0.40320 51...                  Harrow
# 8   MULTIPOLYGON (((-0.19657 51.52765, -0.19685 51...                   Brent
# 9   MULTIPOLYGON (((-0.19990 51.67017, -0.19970 51...                  Barnet
# 10  MULTIPOLYGON (((-0.10580 51.69187, -0.10557 51...                 Enfield
# ...

# %%
import sklearn.preprocessing as preprocessing
scaled = preprocessing.scale(listings[sub_list])

# %%
from sklearn.cluster import KMeans
# calculate SSE for a range of number of cluster
list_SSE = []
min_k = 1
max_k = 10
range_k = range(min_k, max_k+1)
for i in range_k:
    km = KMeans(
        n_clusters=i, init='random',
        n_init=10, max_iter=300,
        tol=1e-04, random_state=0
    )
    km.fit(scaled)
    # inertia is a concept in physics. Roughly it means SSE of clustering.
    list_SSE.append(km.inertia_)

# plot
plt.plot(range_k, list_SSE, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('SSE')
plt.show()

# %%
# perform k-means clustering with 5 clusters determined by elbow plot 
km5 = cluster.KMeans(n_clusters=5)
# fit model to data and drop geometry and neighbourhood cols 
km5cls = km5.fit(zdb.drop(['geometry','neighbourhood'], axis=1).values)

# %%
# add label to dataframe
zdb['km5cls'] = km5cls.labels_

# final dataframe with cluster labels 
zdb
# Out:
#                                              geometry           neighbourhood  \
# 0   MULTIPOLYGON (((-0.33068 51.32901, -0.33059 51...    Kingston upon Thames
# 1   MULTIPOLYGON (((-0.06402 51.31864, -0.06407 51...                 Croydon
# 2   MULTIPOLYGON (((0.01213 51.29960, 0.01196 51.2...                 Bromley
# 3   MULTIPOLYGON (((-0.24456 51.48870, -0.24468 51...                Hounslow
# 4   MULTIPOLYGON (((-0.41183 51.53408, -0.41188 51...                  Ealing
# 5   MULTIPOLYGON (((0.15869 51.51219, 0.15871 51.5...                Havering
# 6   MULTIPOLYGON (((-0.40407 51.61318, -0.40388 51...              Hillingdon
# 7   MULTIPOLYGON (((-0.40407 51.61318, -0.40320 51...                  Harrow
# 8   MULTIPOLYGON (((-0.19657 51.52765, -0.19685 51...                   Brent
# 9   MULTIPOLYGON (((-0.19990 51.67017, -0.19970 51...                  Barnet
# 10  MULTIPOLYGON (((-0.10580 51.69187, -0.10557 51...                 Enfield
# ...

# %%
f, ax = plt.subplots(1, figsize=(9, 9))

zdb.assign(cl=km5cls.labels_)\
   .plot(column='cl', categorical=True, legend=True, \
         linewidth=0.1, edgecolor='white', ax=ax, cmap='Pastel1')

ax.set_axis_off()

plt.show()

# %%
# explore cluster characteristics 
# final dataframe of cluster characteristics 
zdb.groupby('km5cls').mean()
# Out:
#              price  review_scores_rating  review_scores_accuracy  \
# km5cls
# 0       120.915468             93.735081                9.628121
# 1        64.568812             93.411278                9.556542
# 2       206.524685             90.606221                9.333662
# 3        91.617698             93.307167                9.550757
# 4       148.408154             91.400518                9.424211
#
#         review_scores_cleanliness  review_scores_checkin  \
# km5cls
# 0                        9.406159               9.695018
# 1                        9.362473               9.724738
# 2                        9.171313               9.472335
# 3                        9.351739               9.682498
# 4                        9.233450               9.559909
#
#         review_scores_communication  review_scores_location  \
# km5cls
# 0                          9.712660                9.648656
# 1                          9.732397                9.396246
# ...

# %%
# this exports the dataframe of cluster averages to a csv file 
file = zdb.groupby('km5cls').mean()
file.to_csv('cluster.csv')

# %%
## Insert the cluster analysis reuslt with airbnb description data to MySQL

import shapely
from shapely.geometry import LineString, shape, MultiPolygon, Point
from shapely.wkt import dumps

#Reduce the precision of coordinate of polygon to avoid the error 1406 when upload to mySQL
zdb['geometry'] = zdb['geometry'].apply(lambda x: shapely.wkt.loads(shapely.wkt.dumps(x, rounding_precision=4)))

#Convert the coordinates of polygon as WKT string for uploading to mysql
zdb['geometry'] = zdb['geometry'].apply(lambda x: x.wkt)

# %%
# import the SQLAlchemy libraries
from sqlalchemy import create_engine

#Connect to SQL with Character Set utf8mb4
engine = create_engine('mysql+pymysql://ucfnyle:wehomihiga@dev.spatialdatacapture.org:3306/ucfnyle?charset=utf8mb4')

# make the connection to the database
conn = engine.raw_connection()

#Upload the finalized geodataframe to mysql
zdb.to_sql('airbnb_cluster', engine, if_exists='replace')
